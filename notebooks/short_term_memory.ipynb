# %% [markdown]
# # Short-Term Memory

# %%
import dotenv
from agents import Agent, Runner, SQLiteSession, trace

dotenv.load_dotenv()
# Out:
# True

# %%
nutrition_agent = Agent(
    name="Nutrition Assistant",
    instructions="""
    You are a helpful assistant comparing how healthy different foods are.
    If you answer, give a list of how healthy the foods are with a score from 1 to 10. Order by: healtiest food comes first.

    Example:
    Q: Compare X and Y
    A: X is healtier as Y.
    1) X: 8/10 - Very healthy but high in fructose
    2) Y: 3/10 - High in sugar and fat
    """,
)

# %% [markdown]
# ## No Memory

# %%
result = await Runner.run(nutrition_agent, "Which is healthier, bananas or lollipop?")
print(result.final_output)
# Out:
# 1) Bananas: 8/10 - Natural sugars with fiber, potassium, vitamins; good snack in moderation.
# 2) Lollipop: 1/10 - Mostly sugar with no nutrients; quick energy spike and no health benefits.

# %%
result = await Runner.run(nutrition_agent, "Add apples to the comparison")
print(result.final_output)
# Out:
# Please specify the other foods you want to compare apples against. If you’d like a starter, I can compare:
#
# - Apples vs Bananas
# - Apples vs Oranges
# - Apples vs Carrots
#
# Tell me which pair(s) to rate, or provide your own foods.

# %% [markdown]
# ## Short Term Memory

# %%
session = SQLiteSession("conversation_history")

# %%
result = await Runner.run(
    nutrition_agent, "Which is healthier, bananas or lollipop?", session=session
)
print(result.final_output)
# Out:
# 1) Banana: 8/10 - Natural sugars plus potassium, fiber, and vitamins.
# 2) Lollipop: 2/10 - Mostly refined sugar, little to no nutrients.

# %%
with trace("Simple Nutrition Agent"):
    result = await Runner.run(
        nutrition_agent, "Add apples to the comparison", session=session
    )

print(result.final_output)
# Out:
# 1) Banana: 8/10 - Natural sugars, potassium, fiber, vitamins.
# 2) Apple: 7/10 - Fiber, vitamin C, polyphenols; lower sugar impact than bananas.
# 3) Lollipop: 2/10 - Mostly refined sugar, little nutrition.
